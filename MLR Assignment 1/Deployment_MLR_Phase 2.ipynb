# %%
import pickle
loaded_model=pickle.load(open("finalised_MLR.sav",'rb'))
result=loaded_model.predict([[12000,23000,39900,0,1]])
result
# Out:
# C:\Users\FawadSaleem\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[54130.59414877]])

# %%
print(result)
# Out:
# [[54130.59414877]]
