# %%
import pickle

loaded_file= pickle.load(open("Fawad_Salary_Predictor.sav",'rb'))
result= loaded_file.predict([[5]])
# Out:
# C:\Users\FawadSaleem\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[137167.67371601]])

# %%
print (result)
# Out:
# [[137167.67371601]]
