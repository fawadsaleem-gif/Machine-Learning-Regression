# %%
import pickle
loaded_model=pickle.load(open("finalised_SVM.sav",'rb'))
result=loaded_model.predict([[27892,84710,164470,1,0]])
result
# Out:
# array([2.35772262e+09])

# %%
print(result)
# Out:
# [2.35772262e+09]
