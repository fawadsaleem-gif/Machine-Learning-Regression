# %%
import pickle
loaded_model=pickle.load(open("finalised_model_Mul_RF.sav",'rb'))
result=loaded_model.predict([[27892,84710,164470,1,0]])
result
# Out:
# C:\Users\FawadSaleem\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([77634.9022])

# %%
print(result)
# Out:
# [77634.9022]
